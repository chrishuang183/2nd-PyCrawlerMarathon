# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 下載檔案

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"11635567219","type":"PushEvent","actor":{"id":39814207,"login":"pull[bot]","display_login":"pull","gravatar_id":"","url":"https://api.github.com/users/pull[bot]","avatar_url":"https://avatars.githubusercontent.com/u/39814207?"},"repo":{"id":164577447,"name":"osmaelo/tensorflow","url":"https://api.github.com/repos/osmaelo/tensorflow"},"payload":{"push_id":4695332148,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"844b64f2eed4fb6ddc7e893d8baba0e35abd16dd","before":"b87f4a54652d72435a088e5a510ca46e124deccd","commits":[{"sha":"844b64f2eed4fb6ddc7e893d8baba0e35abd16dd","author":{"email":"wangtz@google.com","name":"Tiezhen WANG"},"message":"TensorFlow Lite: Modernize custom operator documentation.\\n\\nSome API has been disabled/renamed even in TF1.\\n\\nPiperOrigin-RevId: 297812988\\nChange-Id: If715ae8249a4b7f8639f5e60c521959715e4db67","distinct":true,"url":"https://api.github.com/repos/osmaelo/tensorflow/commits/844b64f2eed4fb6ddc7e893d8baba0e35abd16dd"}]},"public":true,"created_at":"2020-02-28T12:48:03Z"},{"id":"11635567229","type":"CreateEvent","actor":{"id":54401425,"login":"eswarvarma-dev","display_login":"eswarvarma-dev","gravatar_id":"","url":"https://api.github.com/users/eswarvarma-dev","avatar_url":"https://avatars.githubusercontent.com/u/54401425?"},"repo":{"id":243761021,"name":"eswarvarma-dev/starting-with-typescript-exercise","url":"https://api.github.com/repos/eswarvarma-dev/starting-with-typescript-exercise"},"payload":{"ref":"master","ref_type":"branch","master_branch":"master","description":null,"pusher_type":"user"},"public":true,"created_at":"2020-02-28T12:48:03Z"},{"id":"11635567210","type":"PushEvent","actor":{"id":47556698,"login":"mariksep","display_login":"mariksep","gravatar_id":"","url":"https://api.github.com/users/mariksep","avatar_url":"https://avatars.githubusercontent.com/u/47556698?"},"repo":{"id":240213103,"name":"mariksep/DSdemo","url":"https://api.github.com/repos/mariksep/DSdemo"},"payload":{"push_id":4695332160,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"1bff38484c12e5063417ceda7da66ef8732becd5","before":"3f84ba5271bf3c5d27bea6167d533ce8df5567d6","commits":[{"sha":"1bff38484c12e5063417ceda7da66ef8732becd5","author":{"email":"mari.seppanen4@metropolia.fi","name":"maris"},"message":"myllypuro ja myrtsin ruoka ja hsl","distinct":true,"url":"https://api.github.com/repos/mariksep/DSdemo/commits/1bff38484c12e5063417ceda7da66ef8732becd5"}]},"public":true,"created_at":"2020-02-28T12:48:03Z"},{"id":"11635567226","type":"PushEvent","actor":{"id":61586874,"login":"Zungz","display_login":"Zungz","gravatar_id":"","url":"https://api.github.com/users/Zungz","avatar_url":"https://avatars.githubusercontent.com/u/61586874?"},"repo":{"id":243759867,"name":"Zungz/hello-world","url":"https://api.github.com/repos/Zungz/hello-world"},"payload":{"push_id":4695332171,"size":2,"distinct_size":1,"ref":"refs/heads/master","head":"92875a30eaa77131184ef75e200f4fc8a483eeda","before":"57ebfd50029ba5fa3c8e25e17048bd08311db588","commits":[{"sha":"593ee85d5132f7484ba04dbcaf8bfef0d9f0e5c0","author":{"email":"61586874+Zungz@users.noreply.github.com","name":"Zungz"},"message":"Finish README\\n\\nCorrect me if I\'m wrong","distinct":false,"url":"https://api.github.com/repos/Zungz/hello-world/commits/593ee85d5132f7484ba04dbcaf8bfef0d9f0e5c0"},{"sha":"92875a30eaa77131184ef75e200f4fc8a483eeda","author":{"email":"61586874+Zungz@users.noreply.github.com","name":"Zungz"},"message":"Merge pull request #1 from Zungz/readme-edits\\n\\nFinish README","distinct":true,"url":"https://api.github.com/repos/Zungz/hello-world/commits/92875a30eaa77131184ef75e200f4fc8a483eeda"}]},"public":true,"created_at":"2020-02-28T12:48:03Z"},{"id":"11635567224","type":"IssuesEvent","actor":{"id":37936606,"login":"github-learning-lab[bot]","display_login":"github-learning-lab","gravatar_id":"","url":"https://api.github.com/users/github-learning-lab[bot]","avatar_url":"https://avatars.githubusercontent.com/u/37936606?"},"repo" ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '11635567219',
#   'type': 'PushEvent',
#   'actor': {'id': 39814207,
#    'login': 'pull[bot]',
#    'display_login': 'pull',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pull[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39814207?'},
#   'repo': {'id': 164577447,
#    'name': 'osmaelo/tensorflow',
#    'url': 'https://api.github.com/repos/osmaelo/tensorflow'},
#   'payload': {'push_id': 4695332148,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '844b64f2eed4fb6ddc7e893d8baba0e35abd16dd',
#    'before': 'b87f4a54652d72435a088e5a510ca46e124deccd',
#    'commits': [{'sha': '844b64f2eed4fb6ddc7e893d8baba0e35abd16dd',
#      'author': {'email': 'wangtz@google.com', 'name': 'Tiezhen WANG'},
#      'message': 'TensorFlow Lite: Modernize custom operator documentation.\n\nSome API has been disabled/renamed even in TF1.\n\nPiperOrigin-RevId: 297812988\nChange-Id: If715ae8249a4b7f8639f5e60c521959715e4db67',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/osmaelo/tensorflow/commits/844b64f2eed4fb6ddc7e893d8baba0e35abd16dd'}]},
#   'public': True,
#   'created_at': '2020-02-28T12:48:03Z'},
#  {'id': '11635567229',
#   'type': 'CreateEvent',
#   'actor': {'id': 54401425,
#    'login': 'eswarvarma-dev',
#    'display_login': 'eswarvarma-dev',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/eswarvarma-dev',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54401425?'},
#   'repo': {'id': 243761021,
#    'name': 'eswarvarma-dev/starting-with-typescript-exercise',
#    'url': 'https://api.github.com/repos/eswarvarma-dev/starting-with-typescript-exercise'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-02-28T12:48:03Z'},
#  {'id': '11635567210',
#   'type': 'PushEvent',
#   'actor': {'id': 47556698,
#    'login': 'mariksep',
#    'display_login': 'mariksep',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mariksep',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47556698?'},
#   'repo': {'id': 240213103,
#    'name': 'mariksep/DSdemo',
#    'url': 'https://api.github.com/repos/mariksep/DSdemo'},
#   'payload': {'push_id': 4695332160,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '1bff38484c12e5063417ceda7da66ef8732becd5',
#    'before': '3f84ba5271bf3c5d27bea6167d533ce8df5567d6',
#    'commits': [{'sha': '1bff38484c12e5063417ceda7da66ef8732becd5',
#      'author': {'email': 'mari.seppanen4@metropolia.fi', 'name': 'maris'},
#      'message': 'myllypuro ja myrtsin ruoka ja hsl',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mariksep/DSdemo/commits/1bff38484c12e5063417ceda7da66ef8732becd5'}]},
#   'public': True,
#   'created_at': '2020-02-28T12:48:03Z'},
#  {'id': '11635567226',
#   'type': 'PushEvent',
#   'actor': {'id': 61586874,
#    'login': 'Zungz',
#    'display_login': 'Zungz',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Zungz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61586874?'},
#   'repo': {'id': 243759867,
#    'name': 'Zungz/hello-world',
#    'url': 'https://api.github.com/repos/Zungz/hello-world'},
#   'payload': {'push_id': 4695332171,
#    'size': 2,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '92875a30eaa77131184ef75e200f4fc8a483eeda',
#    'before': '57ebfd50029ba5fa3c8e25e17048bd08311db588',
#    'commits': [{'sha': '593ee85d5132f7484ba04dbcaf8bfef0d9f0e5c0',
#      'author': {'email': '61586874+Zungz@users.noreply.github.com',
#       'name': 'Zungz'},
#      'message': "Finish README\n\nCorrect me if I'm wrong",
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Zungz/hello-world/commits/593ee85d5132f7484ba04dbcaf8bfef0d9f0e5c0'},
#     {'sha': '92875a30eaa77131184ef75e200f4fc8a483eeda',
#      'author': {'email': '61586874+Zungz@users.noreply.github.com',
#       'name': 'Zungz'},
#      'message': 'Merge pull request #1 from Zungz/readme-edits\n\nFinish README',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Zungz/hello-world/commits/92875a30eaa77131184ef75e200f4fc8a483eeda'}]},
#   'public': True,
#   'created_at': '2020-02-28T12:48:03Z'},
#  {'id': '11635567224',
#   'type': 'IssuesEvent',
#   'actor': {'id': 37936606,
#    'login': 'github-learning-lab[bot]',
#    'display_login': 'github-learning-lab',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-learning-lab[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/37936606?'},
#   'repo': {'id': 243761021,
#    'name': 'eswarvarma-dev/starting-with-typescript-exercise',
#    'url': 'https://api.github.com/repos/eswarvarma-dev/starting-with-typescript-exercise'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/eswarvarma-dev/starting-with-typescript-exercise/issues/1',
#     'repository_url': 'https://api.github.com/repos/eswarvarma-dev/starting-with-typescript-exercise',
#     'labels_url': 'https://api.github.com/repos/eswarvarma-dev/starting-with-typescript-exercise/issues/1/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/eswarvarma-dev/starting-with-typescript-exercise/issues/1/comments',
#     'events_url': 'https://api.github.com/repos/eswarvarma-dev/starting-with-typescript-exercise/issues/1/events',
#     'html_url': 'https://github.com/eswarvarma-dev/starting-with-typescript-exercise/issues/1',
#     'id': 572735261,
#     'node_id': 'MDU6SXNzdWU1NzI3MzUyNjE=',
#     'number': 1,
#     'title': 'Welcome to the TypeScript Exercise!',
#     'user': {'login': 'github-learning-lab[bot]',
#      'id': 37936606,
#      'node_id': 'MDM6Qm90Mzc5MzY2MDY=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/in/10572?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/github-learning-lab%5Bbot%5D',
#      'html_url': 'https://github.com/apps/github-learning-lab',
#      'followers_url': 'https://api.github.com/users/github-learning-lab%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/github-learning-lab%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/github-learning-lab%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/github-learning-lab%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/github-learning-lab%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/github-learning-lab%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/github-learning-lab%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/github-learning-lab%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/github-learning-lab%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2020-02-28T12:48:03Z',
#     'updated_at': '2020-02-28T12:48:03Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'body': 'Welcome to this course!\n\nAs soon as you completed each step please close the corresponding issue. The next issue representing the next step will be created automatically.'}},
#   'public': True,
#   'created_at': '2020-02-28T12:48:03Z'},
#  {'id': '11635567208',
#   'type': 'PushEvent',
#   'actor': {'id': 12706143,
#    'login': 'grudloff',
#    'display_login': 'grudloff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/grudloff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12706143?'},
#   'repo': {'id': 232771212,
#    'name': 'grudloff/metric-learn',
#    'url': 'https://api.github.com/repos/grudloff/metric-learn'},
#   'payload': {'push_id': 4695332158,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/add_triplets',
#    'head': '59d253afd7afa08fcd8f6f233ae18f07966084ff',
#    'before': '088b59af9e3e595c7b4d7a649c260656b40619ef',
#    'commits': [{'sha': '59d253afd7afa08fcd8f6f233ae18f07966084ff',
#      'author': {'email': 'gabriel.rudloff@gmail.com', 'name': 'grudloff'},
#      'message': 'closer unlabeled point',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/grudloff/metric-learn/commits/59d253afd7afa08fcd8f6f233ae18f07966084ff'}]},
#   'public': True,
#   'created_at': '2020-02-28T12:48:03Z'},
#  {'id': '11635567216',
#   'type': 'PushEvent',
#   'actor': {'id': 61582328,
#    'login': 'sum-create',
#    'display_login': 'sum-create',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sum-create',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61582328?'},
#   'repo': {'id': 243751442,
#    'name': 'rosemase/planets',
#    'url': 'https://api.github.com/repos/rosemase/planets'},
#   'payload': {'push_id': 4695332153,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '6536addf6aa01054e3236ae1674907986eeabd2c',
#    'before': '9aa8e67305fdcf6052d8de5b09de4a0042fe8839',
#    'commits': [{'sha': '6536addf6aa01054e3236ae1674907986eeabd2c',
#      'author': {'email': 'sumalatars@gmail.com', 'name': 'sum-create'},
#      'message': 'Add notes about Pluto',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/rosemase/planets/commits/6536addf6aa01054e3236ae1674907986eeabd2c'}]},
#   'public': True,
#   'created_at': '2020-02-28T12:48:03Z'},
#  {'id': '11635567201',
#   'type': 'PushEvent',
#   'actor': {'id': 6189810,
#    'login': 'dliotto',
#    'display_login': 'dliotto',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dliotto',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6189810?'},
#   'repo': {'id': 240350388,
#    'name': 'dliotto/api-vision',
#    'url': 'https://api.github.com/repos/dliotto/api-vision'},
#   'payload': {'push_id': 4695332151,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'c0abdef75d51ddb173a4445768cb86c9961fe4e0',
#    'before': '0c3736bcfde75268d8e20ff76845b516b9d9c85e',
#    'commits': [{'sha': 'c0abdef75d51ddb173a4445768cb86c9961fe4e0',
#      'author': {'email': 'douglas.liotto@dwanke.local',
#       'name': 'Douglas Hartmann Liotto'},
#      'message': 'Criada função para reconhecimento de imagem de garrafa',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/dliotto/api-vision/commits/c0abdef75d51ddb173a4445768cb86c9961fe4e0'}]},
#   'public': True,
#   'created_at': '2020-02-28T12:48:03Z'},
#  {'id': '11635567197',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 34771081,
#    'login': 'karlsoderback',
#    'display_login': 'karlsoderback',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/karlsoderback',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/34771081?'},
#   'repo': {'id': 242699719,
#    'name': 'KiriakosD/NLP_Project_TDDE09',
#    'url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09'},
#   'payload': {'action': 'opened',
#    'number': 3,
#    'pull_request': {'url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/pulls/3',
#     'id': 381373380,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzgxMzczMzgw',
#     'html_url': 'https://github.com/KiriakosD/NLP_Project_TDDE09/pull/3',
#     'diff_url': 'https://github.com/KiriakosD/NLP_Project_TDDE09/pull/3.diff',
#     'patch_url': 'https://github.com/KiriakosD/NLP_Project_TDDE09/pull/3.patch',
#     'issue_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/issues/3',
#     'number': 3,
#     'state': 'open',
#     'locked': False,
#     'title': 'Added cuda calls to PerceptronTagger train loop',
#     'user': {'login': 'karlsoderback',
#      'id': 34771081,
#      'node_id': 'MDQ6VXNlcjM0NzcxMDgx',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/34771081?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/karlsoderback',
#      'html_url': 'https://github.com/karlsoderback',
#      'followers_url': 'https://api.github.com/users/karlsoderback/followers',
#      'following_url': 'https://api.github.com/users/karlsoderback/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/karlsoderback/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/karlsoderback/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/karlsoderback/subscriptions',
#      'organizations_url': 'https://api.github.com/users/karlsoderback/orgs',
#      'repos_url': 'https://api.github.com/users/karlsoderback/repos',
#      'events_url': 'https://api.github.com/users/karlsoderback/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/karlsoderback/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '',
#     'created_at': '2020-02-28T12:48:02Z',
#     'updated_at': '2020-02-28T12:48:02Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/pulls/3/commits',
#     'review_comments_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/pulls/3/comments',
#     'review_comment_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/issues/3/comments',
#     'statuses_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/statuses/c6d12b08bb0b5ffa5c175604e12475a08fdd6ced',
#     'head': {'label': 'KiriakosD:feature/cuda',
#      'ref': 'feature/cuda',
#      'sha': 'c6d12b08bb0b5ffa5c175604e12475a08fdd6ced',
#      'user': {'login': 'KiriakosD',
#       'id': 8714981,
#       'node_id': 'MDQ6VXNlcjg3MTQ5ODE=',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/8714981?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/KiriakosD',
#       'html_url': 'https://github.com/KiriakosD',
#       'followers_url': 'https://api.github.com/users/KiriakosD/followers',
#       'following_url': 'https://api.github.com/users/KiriakosD/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/KiriakosD/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/KiriakosD/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/KiriakosD/subscriptions',
#       'organizations_url': 'https://api.github.com/users/KiriakosD/orgs',
#       'repos_url': 'https://api.github.com/users/KiriakosD/repos',
#       'events_url': 'https://api.github.com/users/KiriakosD/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/KiriakosD/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 242699719,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNDI2OTk3MTk=',
#       'name': 'NLP_Project_TDDE09',
#       'full_name': 'KiriakosD/NLP_Project_TDDE09',
#       'private': False,
#       'owner': {'login': 'KiriakosD',
#        'id': 8714981,
#        'node_id': 'MDQ6VXNlcjg3MTQ5ODE=',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/8714981?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/KiriakosD',
#        'html_url': 'https://github.com/KiriakosD',
#        'followers_url': 'https://api.github.com/users/KiriakosD/followers',
#        'following_url': 'https://api.github.com/users/KiriakosD/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/KiriakosD/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/KiriakosD/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/KiriakosD/subscriptions',
#        'organizations_url': 'https://api.github.com/users/KiriakosD/orgs',
#        'repos_url': 'https://api.github.com/users/KiriakosD/repos',
#        'events_url': 'https://api.github.com/users/KiriakosD/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/KiriakosD/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/KiriakosD/NLP_Project_TDDE09',
#       'description': 'Project for TDDE09',
#       'fork': False,
#       'url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09',
#       'forks_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/forks',
#       'keys_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/teams',
#       'hooks_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/hooks',
#       'issue_events_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/events',
#       'assignees_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/tags',
#       'blobs_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/languages',
#       'stargazers_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/stargazers',
#       'contributors_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/contributors',
#       'subscribers_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/subscribers',
#       'subscription_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/subscription',
#       'commits_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/merges',
#       'archive_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/downloads',
#       'issues_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/deployments',
#       'created_at': '2020-02-24T09:51:11Z',
#       'updated_at': '2020-02-25T11:12:59Z',
#       'pushed_at': '2020-02-28T10:08:58Z',
#       'git_url': 'git://github.com/KiriakosD/NLP_Project_TDDE09.git',
#       'ssh_url': 'git@github.com:KiriakosD/NLP_Project_TDDE09.git',
#       'clone_url': 'https://github.com/KiriakosD/NLP_Project_TDDE09.git',
#       'svn_url': 'https://github.com/KiriakosD/NLP_Project_TDDE09',
#       'homepage': None,
#       'size': 32,
#       'stargazers_count': 1,
#       'watchers_count': 1,
#       'language': 'Jupyter Notebook',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 1,
#       'default_branch': 'master'}},
#     'base': {'label': 'KiriakosD:master',
#      'ref': 'master',
#      'sha': 'a1a17566043636b91ef11007c10bc3fcabd62864',
#      'user': {'login': 'KiriakosD',
#       'id': 8714981,
#       'node_id': 'MDQ6VXNlcjg3MTQ5ODE=',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/8714981?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/KiriakosD',
#       'html_url': 'https://github.com/KiriakosD',
#       'followers_url': 'https://api.github.com/users/KiriakosD/followers',
#       'following_url': 'https://api.github.com/users/KiriakosD/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/KiriakosD/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/KiriakosD/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/KiriakosD/subscriptions',
#       'organizations_url': 'https://api.github.com/users/KiriakosD/orgs',
#       'repos_url': 'https://api.github.com/users/KiriakosD/repos',
#       'events_url': 'https://api.github.com/users/KiriakosD/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/KiriakosD/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 242699719,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNDI2OTk3MTk=',
#       'name': 'NLP_Project_TDDE09',
#       'full_name': 'KiriakosD/NLP_Project_TDDE09',
#       'private': False,
#       'owner': {'login': 'KiriakosD',
#        'id': 8714981,
#        'node_id': 'MDQ6VXNlcjg3MTQ5ODE=',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/8714981?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/KiriakosD',
#        'html_url': 'https://github.com/KiriakosD',
#        'followers_url': 'https://api.github.com/users/KiriakosD/followers',
#        'following_url': 'https://api.github.com/users/KiriakosD/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/KiriakosD/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/KiriakosD/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/KiriakosD/subscriptions',
#        'organizations_url': 'https://api.github.com/users/KiriakosD/orgs',
#        'repos_url': 'https://api.github.com/users/KiriakosD/repos',
#        'events_url': 'https://api.github.com/users/KiriakosD/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/KiriakosD/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/KiriakosD/NLP_Project_TDDE09',
#       'description': 'Project for TDDE09',
#       'fork': False,
#       'url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09',
#       'forks_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/forks',
#       'keys_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/teams',
#       'hooks_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/hooks',
#       'issue_events_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/events',
#       'assignees_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/tags',
#       'blobs_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/languages',
#       'stargazers_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/stargazers',
#       'contributors_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/contributors',
#       'subscribers_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/subscribers',
#       'subscription_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/subscription',
#       'commits_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/merges',
#       'archive_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/downloads',
#       'issues_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/deployments',
#       'created_at': '2020-02-24T09:51:11Z',
#       'updated_at': '2020-02-25T11:12:59Z',
#       'pushed_at': '2020-02-28T10:08:58Z',
#       'git_url': 'git://github.com/KiriakosD/NLP_Project_TDDE09.git',
#       'ssh_url': 'git@github.com:KiriakosD/NLP_Project_TDDE09.git',
#       'clone_url': 'https://github.com/KiriakosD/NLP_Project_TDDE09.git',
#       'svn_url': 'https://github.com/KiriakosD/NLP_Project_TDDE09',
#       'homepage': None,
#       'size': 32,
#       'stargazers_count': 1,
#       'watchers_count': 1,
#       'language': 'Jupyter Notebook',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 1,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/pulls/3'},
#      'html': {'href': 'https://github.com/KiriakosD/NLP_Project_TDDE09/pull/3'},
#      'issue': {'href': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/issues/3'},
#      'comments': {'href': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/issues/3/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/pulls/3/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/pulls/3/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/KiriakosD/NLP_Project_TDDE09/statuses/c6d12b08bb0b5ffa5c175604e12475a08fdd6ced'}},
#     'author_association': 'COLLABORATOR',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 31,
#     'deletions': 28,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2020-02-28T12:48:03Z'},
#  {'id': '11635567194',
#   'type': 'PushEvent',
#   'actor': {'id': 23374974,
#    'login': 'jkralik',
#    'display_login': 'jkralik',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jkralik',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23374974?'},
#   'repo': {'id': 182100184,
#    'name': 'go-ocf/grpc-gateway',
#    'url': 'https://api.github.com/repos/go-ocf/grpc-gateway'},
#   'payload': {'push_id': 4695332149,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'b51522563c5404e4e1ef036dec01f8f7d9289398',
#    'before': 'b171f5d0bbe6329493752ea81da9d750a33d1e9c',
#    'commits': [{'sha': 'b51522563c5404e4e1ef036dec01f8f7d9289398',
#      'author': {'email': 'jozef.kralik@kistler.com', 'name': 'Jozef Kralik'},
#      'message': 'mutual tls for mongo/nats',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/go-ocf/grpc-gateway/commits/b51522563c5404e4e1ef036dec01f8f7d9289398'}]},
#   'public': True,
#   'created_at': '2020-02-28T12:48:03Z',
#   'org': {'id': 41510650,
#    'login': 'go-ocf',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/go-ocf',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41510650?'}},
#  {'id': '11635567184',
#   'type': 'PushEvent',
#   'actor': {'id': 57359889,
#    'login': 'Alexlogvin2019',
#    'display_login': 'Alexlogvin2019',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Alexlogvin2019',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57359889?'},
#   'repo': {'id': 242157755,
#    'name': 'Gospodar91/WeatherApp',
#    'url': 'https://api.github.com/repos/Gospodar91/WeatherApp'},
#   'payload': {'push_id': 4695332141,
#    'size': 13,
#    'distinct_size': 3,
#    'ref': 'refs/heads/animationweather',
#    'head': '558a386efdc784c225c32de6c6169a4f92768335',
#    'before': '37999c792e09fd600962856eff1874c56740b024',
#    'commits': [{'sha': '00bae61ba93a5c926836b1ec9bed10e0cee3ba75',
#      'author': {'email': 'arturbohanov1908@gmail.com', 'name': 'unknown'},
#      'message': 'add logic favorites ul',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Gospodar91/WeatherApp/commits/00bae61ba93a5c926836b1ec9bed10e0cee3ba75'},
#     {'sha': 'a418ce26b25577dab865fcee8a2dedfb200f3c9e',
#      'author': {'email': 'arturbohanov1908@gmail.com', 'name': 'unknown'},
#      'message': 'add local storeg YPA',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Gospodar91/WeatherApp/commits/a418ce26b25577dab865fcee8a2dedfb200f3c9e'},
#     {'sha': 'bbb2f16f7879c2af2ebda3ed4a7bbc0dd82429a0',
#      'author': {'email': 'bogdanpechenyk@gmail.com',
#       'name': 'Bogdan Pechenyk'},
#      'message': 'create little logic',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Gospodar91/WeatherApp/commits/bbb2f16f7879c2af2ebda3ed4a7bbc0dd82429a0'},
#     {'sha': '792fd3cb163c1935ca9c7eb3c44c4cd40ced03e4',
#      'author': {'email': 'arturbohanov1908@gmail.com', 'name': 'unknown'},
#      'message': 'add favorites logick localstoreg',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Gospodar91/WeatherApp/commits/792fd3cb163c1935ca9c7eb3c44c4cd40ced03e4'},
#     {'sha': 'f20f5347f4535c88d4f129756753288949b5a19f',
#      'author': {'email': 'arturbohanov1908@gmail.com', 'name': 'unknown'},
#      'message': "Merge branch 'favoritesJS' of https://github.com/Gospodar91/WeatherApp into favoritesJS",
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Gospodar91/WeatherApp/commits/f20f5347f4535c88d4f129756753288949b5a19f'},
#     {'sha': 'f464002704bf74415c6d39c64987d7b13b14f8f4',
#      'author': {'email': 'arturbohanov1908@gmail.com', 'name': 'unknown'},
#      'message': 'pull origin dev',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Gospodar91/WeatherApp/commits/f464002704bf74415c6d39c64987d7b13b14f8f4'},
#     {'sha': '363bc3d40c719cfa4a82ed1e220214dd937429dd',
#      'author': {'email': 'arturbohanov1908@gmail.com', 'name': 'unknown'},
#      'message': 'add all logick LocalStoreg',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Gospodar91/WeatherApp/commits/363bc3d40c719cfa4a82ed1e220214dd937429dd'},
#     {'sha': '4d6ca27fa51d84882d1dd9e22a6984331a1e2e69',
#      'author': {'email': 'arturbohanov1908@gmail.com', 'name': 'unknown'},
#      'message': 'add slider favorites',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Gospodar91/WeatherApp/commits/4d6ca27fa51d84882d1dd9e22a6984331a1e2e69'},
#     {'sha': '9702a300582a504e74efdab4450e26aa98a4b8da',
#      'author': {'email': 'arturbohanov1908@gmail.com', 'name': 'unknown'},
#      'message': 'pull origin dev 1',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Gospodar91/WeatherApp/commits/9702a300582a504e74efdab4450e26aa98a4b8da'},
#     {'sha': '7202b73ca3426f9d398bb38d09daec38b88e2807',
#      'author': {'email': '51333042+Gospodar91@users.noreply.github.com',
#       'name': 'Gospodar91'},
#      'message': 'Merge pull request #61 from Gospodar91/favoritesJS\n\nFavorites js',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Gospodar91/WeatherApp/commits/7202b73ca3426f9d398bb38d09daec38b88e2807'},
#     {'sha': 'b92a529431ff0cb741f0ba5f6e1df8202a30812c',
#      'author': {'email': 'alexlogvin@yahoo.com', 'name': 'Alexlogvin2019'},
#      'message': "Merge branch 'dev' into animationweather",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Gospodar91/WeatherApp/commits/b92a529431ff0cb741f0ba5f6e1df8202a30812c'},
#     {'sha': '46dff6e70b5c156815ff116dfbdb840c9d3636ef',
#      'author': {'email': 'alexlogvin@yahoo.com', 'name': 'Alexlogvin2019'},
#      'message': 'ver4',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Gospodar91/WeatherApp/commits/46dff6e70b5c156815ff116dfbdb840c9d3636ef'},
#     {'sha': '558a386efdc784c225c32de6c6169a4f92768335',
#      'author': {'email': 'alexlogvin@yahoo.com', 'name': 'Alexlogvin2019'},
#      'message': 'finalwith hours',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Gospodar91/WeatherApp/commits/558a386efdc784c225c32de6c6169a4f92768335'}]},
#   'public': True,
#   'created_at': '2020-02-28T12:48:03Z'},
#  {'id': '11635567177',
#   'type': 'PushEvent',
#   'actor': {'id': 43139703,
#    'login': 'BergEB',
#    'display_login': 'BergEB',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/BergEB',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/43139703?'},
#   'repo': {'id': 242811018,
#    'name': 'BergEB/ACSLabs',
#    'url': 'https://api.github.com/repos/BergEB/ACSLabs'},
#   'payload': {'push_id': 4695332138,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '630293caca1cdf31cb1c53a89915847e0b126f96',
#    'before': 'e39944bfb460dc203abd24b7d3a7f78d7360ab47',
#    'commits': [{'sha': '630293caca1cdf31cb1c53a89915847e0b126f96',
#      'author': {'email': '43139703+BergEB@users.noreply.github.com',
#       'name': 'BergEB'},
#      'message': 'cdgfgxdzxsdfvyae\n\ndvasdrvSWE',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/BergEB/ACSLabs/commits/630293caca1cdf31cb1c53a89915847e0b126f96'}]},
#   'public': True,
#   'created_at': '2020-02-28T12:48:03Z'},
#  {'id': '11635567181',
#   'type': 'PushEvent',
#   'actor': {'id': 21002501,
#    'login': 'an-tao',
#    'display_login': 'an-tao',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/an-tao',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/21002501?'},
#   'repo': {'id': 131236938,
#    'name': 'an-tao/drogon',
#    'url': 'https://api.github.com/repos/an-tao/drogon'},
#   'payload': {'push_id': 4695332152,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/dev',
#    'head': 'b0a89265564aa299af34299001b98a767bb2a206',
#    'before': '0b75c7560f88078d83380594a7acc0092efcc52b',
#    'commits': [{'sha': 'b0a89265564aa299af34299001b98a767bb2a206',
#      'author': {'email': 'antao2002@gmail.com', 'name': 'antao'},
#      'message': 'Fix CI5',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/an-tao/drogon/commits/b0a89265564aa299af34299001b98a767bb2a206'}]},
#   'public': True,
#   'created_at': '2020-02-28T12:48:03Z'},
#  {'id': '11635567189',
#   'type': 'CreateEvent',
#   'actor': {'id': 591304,
#    'login': 'dVelopment',
#    'display_login': 'dVelopment',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dVelopment',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/591304?'},
#   'repo': {'id': 243761033,
#    'name': 'dVelopment/gatsby-homepage',
#    'url': 'https://api.github.com/repos/dVelopment/gatsby-homepage'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-02-28T12:48:03Z'},
#  {'id': '11635567173',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 11370192,
#    'login': 'rgrams',
#    'display_login': 'rgrams',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rgrams',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11370192?'},
#   'repo': {'id': 107326978,
#    'name': 'rgrams/rendercam',
#    'url': 'https://api.github.com/repos/rgrams/rendercam'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/rgrams/rendercam/issues/39',
#     'repository_url': 'https://api.github.com/repos/rgrams/rendercam',
#     'labels_url': 'https://api.github.com/repos/rgrams/rendercam/issues/39/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/rgrams/rendercam/issues/39/comments',
#     'events_url': 'https://api.github.com/repos/rgrams/rendercam/issues/39/events',
#     'html_url': 'https://github.com/rgrams/rendercam/issues/39',
#     'id': 570266650,
#     'node_id': 'MDU6SXNzdWU1NzAyNjY2NTA=',
#     'number': 39,
#     'title': 'Problem with pick node with arbitrary gui position',
#     'user': {'login': 'subsoap',
#      'id': 409170,
#      'node_id': 'MDQ6VXNlcjQwOTE3MA==',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/409170?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/subsoap',
#      'html_url': 'https://github.com/subsoap',
#      'followers_url': 'https://api.github.com/users/subsoap/followers',
#      'following_url': 'https://api.github.com/users/subsoap/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/subsoap/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/subsoap/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/subsoap/subscriptions',
#      'organizations_url': 'https://api.github.com/users/subsoap/orgs',
#      'repos_url': 'https://api.github.com/users/subsoap/repos',
#      'events_url': 'https://api.github.com/users/subsoap/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/subsoap/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2020-02-25T02:23:17Z',
#     'updated_at': '2020-02-28T12:48:03Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'body': 'What am I misunderstanding about how this should work?\r\n\r\nAttached sample project, press wasd or mouse to move cursor position. When screen is not resized it works. When screen resizes it does not work. What am I missing?\r\n\r\n![2020-02-24 18_20_50-GamepadGUITester](https://user-images.githubusercontent.com/409170/75209210-8f288480-5732-11ea-9d2d-06becf9f3c06.png)\r\n\r\n\r\n[GamepadGUITester.zip](https://github.com/rgrams/rendercam/files/4247767/GamepadGUITester.zip)\r\n\r\n\r\n```\r\nlocal rendercam = require("rendercam.rendercam")\r\n\r\nlocal move_speed = 10\r\nlocal left = vmath.vector3(-1,0,0)\r\nlocal right = vmath.vector3(1,0,0)\r\nlocal up = vmath.vector3(0,1,0)\r\nlocal down = vmath.vector3(0,-1,0)\r\n\r\nlocal cursor_node\r\nlocal button_node\r\n\r\nlocal function check_button(self)\r\n\tlocal position = rendercam.world_to_screen(self.cursor_world_position, gui.ADJUST_FIT)\r\n\tlocal x, y = rendercam.screen_to_gui_pick(position.x, position.y)\r\n\tif gui.pick_node(button_node, position.x, position.y) then\r\n\t\tgui.set_color(button_node, vmath.vector4(0,1,0,1))\r\n\telse\r\n\t\tgui.set_color(button_node, vmath.vector4(1,0,0,1))\r\n\tend\r\nend\r\n\r\nlocal function update_cursor_position(self)\r\n\tlocal position = rendercam.world_to_screen(self.cursor_world_position, gui.ADJUST_FIT)\r\n\tgui.set_position(cursor_node, position)\r\n\t--print(self.cursor_world_position, position)\r\n\tcheck_button(self)\r\nend\r\n\r\n\r\nfunction init(self)\r\n\tcursor_node = gui.get_node("cursor")\r\n\tbutton_node = gui.get_node("button")\r\n\t\r\n\tmsg.post(".", "acquire_input_focus")\r\n\tself.cursor_world_position = vmath.vector3(0,0,0)\r\nend\r\n\r\nfunction final(self)\r\n\t-- Add finalization code here\r\n\t-- Remove this function if not needed\r\nend\r\n\r\nfunction update(self, dt)\r\n\t\r\nend\r\n\r\nfunction on_message(self, message_id, message, sender)\r\n\t-- Add message-handling code here\r\n\t-- Remove this function if not needed\r\nend\r\n\r\nfunction on_input(self, action_id, action)\r\n\tif action_id == nil then\r\n\t\tself.cursor_world_position = rendercam.screen_to_world_2d(action.screen_x, action.screen_y)\r\n\t\tupdate_cursor_position(self)\r\n\tend\r\n\t\r\n\tif action_id == hash("key_w") then\r\n\t\tself.cursor_world_position = self.cursor_world_position + up * move_speed\r\n\t\tupdate_cursor_position(self)\r\n\tend\r\n\tif action_id == hash("key_a") then\r\n\t\tself.cursor_world_position = self.cursor_world_position + left * move_speed\r\n\t\tupdate_cursor_position(self)\r\n\tend\r\n\tif action_id == hash("key_s") then\r\n\t\tself.cursor_world_position = self.cursor_world_position + down * move_speed\r\n\t\tupdate_cursor_position(self)\r\n\tend\r\n\tif action_id == hash("key_d") then\r\n\t\tself.cursor_world_position = self.cursor_world_position + right * move_speed\r\n\t\tupdate_cursor_position(self)\r\n\tend\r\nend\r\n\r\nfunction on_reload(self)\r\n\t-- Add input-handling code here\r\n\t-- Remove this function if not needed\r\nend\r\n\r\n```\r\n'},
#    'comment': {'url': 'https://api.github.com/repos/rgrams/rendercam/issues/comments/592498314',
#     'html_url': 'https://github.com/rgrams/rendercam/issues/39#issuecomment-592498314',
#     'issue_url': 'https://api.github.com/repos/rgrams/rendercam/issues/39',
#     'id': 592498314,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU5MjQ5ODMxNA==',
#     'user': {'login': 'rgrams',
#      'id': 11370192,
#      'node_id': 'MDQ6VXNlcjExMzcwMTky',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/11370192?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/rgrams',
#      'html_url': 'https://github.com/rgrams',
#      'followers_url': 'https://api.github.com/users/rgrams/followers',
#      'following_url': 'https://api.github.com/users/rgrams/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/rgrams/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/rgrams/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/rgrams/subscriptions',
#      'organizations_url': 'https://api.github.com/users/rgrams/orgs',
#      'repos_url': 'https://api.github.com/users/rgrams/repos',
#      'events_url': 'https://api.github.com/users/rgrams/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/rgrams/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2020-02-28T12:48:03Z',
#     'updated_at': '2020-02-28T12:48:03Z',
#     'author_association': 'OWNER',
#     'body': "That's quite the merry-go-round of transformations you have there! I checked it out a bit but haven't sorted out where exactly the problem is. But what exactly do you want to do? Do you want to control your gamepad cursor in world space (and be changed by camera zoom, etc.), or screen space? Or could it maybe be a gui node and maybe you wouldn't have to do any conversion at all?"}},
#   'public': True,
#   'created_at': '2020-02-28T12:48:03Z'},
#  {'id': '11635567164',
#   'type': 'CreateEvent',
#   'actor': {'id': 47148648,
#    'login': 'svc-software-factory',
#    'display_login': 'svc-software-factory',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/svc-software-factory',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47148648?'},
#   'repo': {'id': 197735571,
#    'name': 'adeo-gitlab/sync-github-gitlab-13',
#    'url': 'https://api.github.com/repos/adeo-gitlab/sync-github-gitlab-13'},
#   'payload': {'ref': '2020-02-28_12-47-51_851_scenario1',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-02-28T12:48:03Z',
#   'org': {'id': 52697831,
#    'login': 'adeo-gitlab',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/adeo-gitlab',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52697831?'}},
#  {'id': '11635567169',
#   'type': 'WatchEvent',
#   'actor': {'id': 47018658,
#    'login': 'nchen194',
#    'display_login': 'nchen194',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nchen194',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47018658?'},
#   'repo': {'id': 243744259,
#    'name': 'nchen194/actions-openwrt-passwall',
#    'url': 'https://api.github.com/repos/nchen194/actions-openwrt-passwall'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-02-28T12:48:03Z'},
#  {'id': '11635567162',
#   'type': 'PushEvent',
#   'actor': {'id': 14079465,
#    'login': 'brunats',
#    'display_login': 'brunats',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/brunats',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/14079465?'},
#   'repo': {'id': 169822336,
#    'name': 'brunats/chewie',
#    'url': 'https://api.github.com/repos/brunats/chewie'},
#   'payload': {'push_id': 4695332129,
#    'size': 2,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '0a5b560d5d17598bda8c23eaa0549b17f1d8d288',
#    'before': '5cb97b85b2061d7ff5e258a98eddd9d55ffa1a33',
#    'commits': [{'sha': '6a3542a128b37ce0bf9e94ed52cfec4821bb7108',
#      'author': {'email': '49699333+dependabot[bot]@users.noreply.github.com',
#       'name': 'dependabot[bot]'},
#      'message': 'Bump nokogiri from 1.10.3 to 1.10.8\n\nBumps [nokogiri](https://github.com/sparklemotion/nokogiri) from 1.10.3 to 1.10.8.\n- [Release notes](https://github.com/sparklemotion/nokogiri/releases)\n- [Changelog](https://github.com/sparklemotion/nokogiri/blob/master/CHANGELOG.md)\n- [Commits](https://github.com/sparklemotion/nokogiri/compare/v1.10.3...v1.10.8)\n\nSigned-off-by: dependabot[bot] <support@github.com>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/brunats/chewie/commits/6a3542a128b37ce0bf9e94ed52cfec4821bb7108'},
#     {'sha': '0a5b560d5d17598bda8c23eaa0549b17f1d8d288',
#      'author': {'email': 'silvatavares.bruna@gmail.com',
#       'name': 'Bruna Tavares Silva'},
# ...
#       'issue_comment_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/merges',
#       'archive_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/downloads',
#       'issues_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/deployments',
#       'created_at': '2019-04-18T14:13:17Z',
#       'updated_at': '2020-02-07T12:50:05Z',
#       'pushed_at': '2020-02-28T12:48:02Z',
#       'git_url': 'git://github.com/go-ocf/grpc-gateway.git',
#       'ssh_url': 'git@github.com:go-ocf/grpc-gateway.git',
#       'clone_url': 'https://github.com/go-ocf/grpc-gateway.git',
#       'svn_url': 'https://github.com/go-ocf/grpc-gateway',
#       'homepage': None,
#       'size': 261,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Go',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 6,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'forks': 0,
#       'open_issues': 6,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'go-ocf:master',
#      'ref': 'master',
#      'sha': 'b171f5d0bbe6329493752ea81da9d750a33d1e9c',
#      'user': {'login': 'go-ocf',
#       'id': 41510650,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQxNTEwNjUw',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/41510650?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/go-ocf',
#       'html_url': 'https://github.com/go-ocf',
#       'followers_url': 'https://api.github.com/users/go-ocf/followers',
#       'following_url': 'https://api.github.com/users/go-ocf/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/go-ocf/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/go-ocf/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/go-ocf/subscriptions',
#       'organizations_url': 'https://api.github.com/users/go-ocf/orgs',
#       'repos_url': 'https://api.github.com/users/go-ocf/repos',
#       'events_url': 'https://api.github.com/users/go-ocf/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/go-ocf/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 182100184,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxODIxMDAxODQ=',
#       'name': 'grpc-gateway',
#       'full_name': 'go-ocf/grpc-gateway',
#       'private': False,
#       'owner': {'login': 'go-ocf',
#        'id': 41510650,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQxNTEwNjUw',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/41510650?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/go-ocf',
#        'html_url': 'https://github.com/go-ocf',
#        'followers_url': 'https://api.github.com/users/go-ocf/followers',
#        'following_url': 'https://api.github.com/users/go-ocf/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/go-ocf/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/go-ocf/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/go-ocf/subscriptions',
#        'organizations_url': 'https://api.github.com/users/go-ocf/orgs',
#        'repos_url': 'https://api.github.com/users/go-ocf/repos',
#        'events_url': 'https://api.github.com/users/go-ocf/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/go-ocf/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/go-ocf/grpc-gateway',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/go-ocf/grpc-gateway',
#       'forks_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/forks',
#       'keys_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/teams',
#       'hooks_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/hooks',
#       'issue_events_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/events',
#       'assignees_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/tags',
#       'blobs_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/languages',
#       'stargazers_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/stargazers',
#       'contributors_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/contributors',
#       'subscribers_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/subscribers',
#       'subscription_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/subscription',
#       'commits_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/merges',
#       'archive_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/downloads',
#       'issues_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/go-ocf/grpc-gateway/deployments',
#       'created_at': '2019-04-18T14:13:17Z',
#       'updated_at': '2020-02-07T12:50:05Z',
#       'pushed_at': '2020-02-28T12:48:02Z',
#       'git_url': 'git://github.com/go-ocf/grpc-gateway.git',
#       'ssh_url': 'git@github.com:go-ocf/grpc-gateway.git',
#       'clone_url': 'https://github.com/go-ocf/grpc-gateway.git',
#       'svn_url': 'https://github.com/go-ocf/grpc-gateway',
#       'homepage': None,
#       'size': 261,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Go',
#       'has_issues': True,
#       'has_projects': False,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 6,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'forks': 0,
#       'open_issues': 6,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/go-ocf/grpc-gateway/pulls/62'},
#      'html': {'href': 'https://github.com/go-ocf/grpc-gateway/pull/62'},
#      'issue': {'href': 'https://api.github.com/repos/go-ocf/grpc-gateway/issues/62'},
#      'comments': {'href': 'https://api.github.com/repos/go-ocf/grpc-gateway/issues/62/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/go-ocf/grpc-gateway/pulls/62/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/go-ocf/grpc-gateway/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/go-ocf/grpc-gateway/pulls/62/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/go-ocf/grpc-gateway/statuses/65cb2216413e5173f4a8196f109d6b7b65d1bd49'}},
#     'author_association': 'MEMBER',
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'jkralik',
#      'id': 23374974,
#      'node_id': 'MDQ6VXNlcjIzMzc0OTc0',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/23374974?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/jkralik',
#      'html_url': 'https://github.com/jkralik',
#      'followers_url': 'https://api.github.com/users/jkralik/followers',
#      'following_url': 'https://api.github.com/users/jkralik/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/jkralik/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/jkralik/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/jkralik/subscriptions',
#      'organizations_url': 'https://api.github.com/users/jkralik/orgs',
#      'repos_url': 'https://api.github.com/users/jkralik/repos',
#      'events_url': 'https://api.github.com/users/jkralik/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/jkralik/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 91,
#     'deletions': 54,
#     'changed_files': 8}},
#   'public': True,
#   'created_at': '2020-02-28T12:48:02Z',
#   'org': {'id': 41510650,
#    'login': 'go-ocf',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/go-ocf',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41510650?'}},
#  {'id': '11635567081',
#   'type': 'PushEvent',
#   'actor': {'id': 16756616,
#    'login': 'vchlum',
#    'display_login': 'vchlum',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/vchlum',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16756616?'},
#   'repo': {'id': 61615522,
#    'name': 'CESNET/pbspro',
#    'url': 'https://api.github.com/repos/CESNET/pbspro'},
#   'payload': {'push_id': 4695332073,
#    'size': 5,
#    'distinct_size': 0,
#    'ref': 'refs/heads/master',
#    'head': '4dcb85b01b990e0a3b529011c9d9a0d34cc2c8b7',
#    'before': '438e74bb13ead301f2508411e13fb3311b5ac52d',
#    'commits': [{'sha': '742f7582c09d331fc2678a185d8be71a1cbf5343',
#      'author': {'email': 'vincents.995@gmail.com', 'name': 'Vincent Stumpf'},
#      'message': 'Add Authorized_Users/Groups options to pbs_ralter (#1538)',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/CESNET/pbspro/commits/742f7582c09d331fc2678a185d8be71a1cbf5343'},
#     {'sha': '6805c4828925e1ff93438a2f6e89e98bc0db0f0a',
#      'author': {'email': '37452058+birbalsain@users.noreply.github.com',
#       'name': 'birbal'},
#      'message': 'added hook name to match hook attributes (#1541)',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/CESNET/pbspro/commits/6805c4828925e1ff93438a2f6e89e98bc0db0f0a'},
#     {'sha': '9da7f3fa5127e21845bb4c0c6b51107a294aa0a2',
#      'author': {'email': 'arun.grover@altair.com', 'name': 'Arun Grover'},
#      'message': 'Modified svr_dyn_res test to work with sudo rules (#1543)',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/CESNET/pbspro/commits/9da7f3fa5127e21845bb4c0c6b51107a294aa0a2'},
#     {'sha': 'b65ea5c996b6e0875d4140d05a1536bdaf171897',
#      'author': {'email': '33057352+shilpakodli@users.noreply.github.com',
#       'name': 'shilpakodli'},
#      'message': 'Add absolute path for qselect command (#1527)',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/CESNET/pbspro/commits/b65ea5c996b6e0875d4140d05a1536bdaf171897'},
#     {'sha': '4dcb85b01b990e0a3b529011c9d9a0d34cc2c8b7',
#      'author': {'email': 'chlumskyvaclav@gmail.com',
#       'name': 'Václav Chlumský'},
#      'message': 'afslog should be done in forked process (#1439)\n\n* afslog should be done in forked process\r\n\r\n* comment style fix\r\n\r\n* cred action: add missing string\r\n\r\n* address comments from Michael\r\n\r\n* address comments from Michael 2\r\n\r\n* forked process should close local logfile; afslog logging goes to syslog only\r\n\r\n* change euid for singleshot_afslog\r\n\r\n* add space after IFs\r\n\r\n* reset root privileges on start_afslog error fix',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/CESNET/pbspro/commits/4dcb85b01b990e0a3b529011c9d9a0d34cc2c8b7'}]},
#   'public': True,
#   'created_at': '2020-02-28T12:48:02Z',
#   'org': {'id': 1116469,
#    'login': 'CESNET',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/CESNET',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1116469?'}},
#  {'id': '11635567084',
#   'type': 'PushEvent',
#   'actor': {'id': 961604,
#    'login': 'raveit65',
#    'display_login': 'raveit65',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/raveit65',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/961604?'},
#   'repo': {'id': 2728053,
#    'name': 'mate-desktop/eom',
#    'url': 'https://api.github.com/repos/mate-desktop/eom'},
#   'payload': {'push_id': 4695332051,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/1.24',
#    'head': 'ac3e574df279cd2b5f1451e96bb0bf613dbc2727',
#    'before': '6847212da35d85a302038d969480b7031a91645d',
#    'commits': [{'sha': 'ac3e574df279cd2b5f1451e96bb0bf613dbc2727',
#      'author': {'email': 'rbuj@users.noreply.github.com',
#       'name': 'Robert Antoni Buj Gelonch'},
#      'message': 'help: Fix Image Collection shortcut (#263)\n\n* help: Fix Image Collection shortcut\r\n\r\n* image collection shortcut fix on another section\r\n\r\nCo-authored-by: Mohammad Abu Sakib <mabusakib@gmail.com>',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mate-desktop/eom/commits/ac3e574df279cd2b5f1451e96bb0bf613dbc2727'}]},
#   'public': True,
#   'created_at': '2020-02-28T12:48:02Z',
#   'org': {'id': 1236121,
#    'login': 'mate-desktop',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/mate-desktop',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1236121?'}}]

# %% [markdown]
# ## 其它用法

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get("http://httpbin.org/get", params=payload)
json.loads(r.text)
# Out:
# {'args': {'key1': 'value1', 'key2': 'value2'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0',
#   'X-Amzn-Trace-Id': 'Root=1-5e590d4d-3bd4bf50e8a8593ccdf09546'},
#  'origin': '220.132.53.216',
#  'url': 'http://httpbin.org/get?key1=value1&key2=value2'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0',
#   'X-Amzn-Trace-Id': 'Root=1-5e590d51-c447fade03d1bc1bcb062b86'},
#  'json': None,
#  'origin': '220.132.53.216',
#  'url': 'http://httpbin.org/post'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0',
#   'X-Amzn-Trace-Id': 'Root=1-5e590d54-5c16499d7d45fac2c106e99c'},
#  'json': None,
#  'origin': '220.132.53.216',
#  'url': 'http://httpbin.org/post'}

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)
